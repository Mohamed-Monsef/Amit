# %% [markdown]
# Try

# %%
try:
    5/0
except:
    print("No acception to divide by zero")
# Out:
# No acception to divide by zero

# %%
try:
    x = 10
    y = int(input())
    x/y
except:
    print("Division By Zero")
else:
    print("Shokran")
finally:
    print("Done")
# Out:
# Division By Zero
# Done

# %%
import random
n = random.random()

# %%
random.randint(1,10)
# Out:
# 7

# %%
list = ["ahmed","ali",5,8]
random.choice(list)
# Out:
# 'ali'

# %%
list = ["ahmed","ali",5,8]
random.choices(list, k=2)
# Out:
# [5, 'ahmed']

# %%
import os

# %%
base = "D:/Projects/DEPI_AIS2_ml/Amit/AI & Data Science/src/python/session_3"
type(base)
# Out:
# str

# %%
file = os.listdir(base)

# %%
print(type(file))
# Out:
# <class 'list'>

# %%
base_dir = "./tmp_directory"
file_name = "text_1.txt"
file_path = os.path.join(base_dir,file_name)
file_path
# Out:
# './tmp_directory\\text_1.txt'

# %%
import os 
os.remove("D:/Projects/DEPI_AIS2_ml/Amit/AI & Data Science/src/python/session_3/rm.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 import os
# ----> 2 os.remove("D:/Projects/DEPI_AIS2_ml/Amit/AI & Data Science/src/python/session_3/rm.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'D:/Projects/DEPI_AIS2_ml/Amit/AI & Data Science/src/python/session_3/rm.txt'

# %%
import os
directory = "./tmp_directory_test"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("Directory File Exists: ", directory)
# Out:
# Directory File Exists:  ./tmp_directory_test

# %%
import os 
path = "tmp_directory"

if not os.path.exists(path):
    os.makedirs(path)
for i in range(20):
    inner_path = os.path.join(path, "dir_" + str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %% [markdown]
# READ AND WRITE FILES

# %%
with open("./tmp_directory/text_1.txt","a+") as file:
    file.write("New File added\n")
    file.seek(0)
    update_content = file.read()
    print(update_content)
# Out:
# New File added
