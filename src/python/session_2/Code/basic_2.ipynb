# %%
list_one = ["DEPI","Learning","ml"]
list_one.append("dl")

# %%
list_one
# Out:
# ['DEPI', 'Learning', 'ml', 'dl']

# %%
list_one.insert(0,"genAI")

# %%
list_one
# Out:
# ['genAI', 'genAI', 'DEPI', 'Learning', 'ml', 'dl']

# %%
list_1 = [1,2,3]
list_2 = [4,5,6]
x = list_1 + list_2

# %%
list_1.extend(list_2)

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_one = ["DEPI","Learning","learning","ml"]
list_one.remove("learning")
print(list_one)
# Out:
# ['DEPI', 'Learning', 'ml']

# %%
list_one = ["DEPI","Learning","learning","ml"]
list_one.pop()
print(list_one)
# Out:
# ['DEPI', 'Learning', 'learning']

# %%
list_one = ["DEPI","Learning","learning","ml"]
x = list_one.pop()
print(x)
# Out:
# ml

# %%
list_one = ["DEPI","Learning","learning","ml"]
del list_one[1:]
print(list_one)
# Out:
# ['DEPI']

# %%
list_one = ["DEPI","Learning","learning","ml"]
del list_one
print(list_one)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 list_one = ["DEPI","Learning","learning","ml"]
#       2 del list_one
# ----> 3 print(list_one)
#
# NameError: name 'list_one' is not defined

# %%
x = input()
print(type(x))
# Out:
# <class 'str'>

# %%
name = input("Enter Your Name")
id = input("Enter Your ID")

print(f"Your Name Is: {name}, and your ID Number is: {id}")
# Out:
# Your Name Is: Mohamed, and your ID Number is: 81509

# %%
item_list= ["amit","learning","python","machine learning"]

# %%
item = input("enter the item to remove")
item_list.remove(item)

# %%
item_list
# Out:
# ['amit', 'python', 'machine learning']

# %%
list_3 = [1,2,2,4]
list_3.index(2)
# Out:
# 1

# %%
list_4 = [1,2,2,4]
list_3.count(2)
# Out:
# 2

# %%
list_5 = [50,33,21,105]
list_5.sort()
list_5
# Out:
# [21, 33, 50, 105]

# %%
tuple_1 = (50,33,21,105)
item = 5
print(type(tuple_1))
# 34an t8yr fel tuple lazm t7tha fe list    
list(tuple_1)
new_list = list(tuple_1).append(item)
print(new_list)
# Out:
# <class 'tuple'>
# None

# %%
set_1 ={1,2,3}
type(set_1)
set_2 = {3,4,5}
set_1.intersection(set_2)
# Out:
# {3}

# %%
set_1.difference(set_2)
# Out:
# {1, 2}

# %%
dict_1 = {"key_1":12.5,"Key_2":"DEPI"}
type(dict_1)
dict
# Out:
# dict

# %%
dict_1["key_1"]
# Out:
# 12.5

# %%
items = ("a",1),("b",2),("c",3)
new_dict = dict(items)
print(new_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num = int(input("enter your number"))
print(num)
# Out:
# 40

# %%
num_1 = int(input("Enter First Num"))
num_2 = int(input("Enter Second Num"))
print(f"Sum {num_1 + num_2}\n sub{num_1 - num_2}\n Div {num_1/num_2}\n Multi {num_1 * num_2}")
# Out:
# Sum 30
#  sub-10
#  Div 0.5
#  Multi 200

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
elif b == a:
    print("a and b are equal")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 5
y = 10
if x > 0 and y > 0:
    print("both x and y are positive.")
# Out:
# both x and y are positive.

# %%
x = 5
result = "Even" if x % 2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
a = 10
b = 5 
result =  a + b if a > b else a - b
print(result)
# Out:
# 15

# %%
age = 21
print("adult") if age >= 18 else (print("Teenager") if age <= 13 print("Child"))
# Out:
#   Cell In[45], line 2
#     print("adult") if age >= 18 else print("Teenager") if age <= 13 print("Child")
#                                      ^
# SyntaxError: expected 'else' after 'if' expression

# %%
std_grade = int(input("Enter your degree"))
if 0 < std_grade <= 100:
    if 90 <= std_grade <= 100:
        print("A")
    elif 80 <= std_grade < 90:
        print("B")
    elif 70 <= std_grade < 80:
        print("C")
    elif 60 <= std_grade < 70:
        print("D")
    else: print("F")
else:
    print("You Must Enter a Value between 0 to 100")
# Out:
# You Must Enter a Value between 0 to 100

# %%
for i in "DEPI":
    print(i, "ml")
else:
    print("finished")
# Out:
# D ml
# E ml
# P ml
# I ml
# finished

# %%
for i in range(10):
    print(i,"ml")
else:
    print("finished")
# Out:
# 0 ml
# 1 ml
# 2 ml
# 3 ml
# 4 ml
# 5 ml
# 6 ml
# 7 ml
# 8 ml
# 9 ml
# finished

# %%
for i in range(6):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2
