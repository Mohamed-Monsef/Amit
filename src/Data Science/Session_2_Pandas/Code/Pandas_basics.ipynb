# %% [markdown]
# <h1> Pandas </h1>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\muham\Downloads\test.csv")

# %%
df
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
df.tail()
# Out:
#     Id  EmployeeName                            JobTitle    BasePay  \
# 35  36    KHOA TRINH   ELECTRONIC MAINTENANCE TECHNICIAN  101953.20
# 36  37  SUSAN CURRIN  ADMINISTRATOR, SFGH MEDICAL CENTER  245124.44
# 37  38   JAMES BOSCH  INSPECTOR III, (POLICE DEPARTMENT)  110661.20
# 38  39    JONES WONG  LIEUTENANT III (POLICE DEPARTMENT)  132202.26
# 39  40  BRENDAN WARD  BATTALION CHIEF, (FIRE DEPARTMENT)  147158.85
#
#     OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 35    139102.95   16483.94       NaN  257540.09         257540.09  2011
# 36         0.00   12000.00       NaN  257124.44         257124.44  2011
# 37     31162.04  111446.20       NaN  253269.44         253269.44  2011
# 38     52648.92   67083.83       NaN  251935.01         251935.01  2011
# 39     64985.85   39540.46       NaN  251685.16         251685.16  2011

# %%
s = pd.Series([1,2,3,4],index=["A","B","C","D"])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data =  [[1,444,"abc",],
         [2,555,"def"],
         [3,666,"ghi"],
         [4,777,"xyz"]]
df  = pd.DataFrame(data, columns=["index","id","name"])
display(df)
# Out:
#    index   id name
# 0      1  444  abc
# 1      2  555  def
# 2      3  666  ghi
# 3      4  777  xyz

# %%
df.dtypes
# Out:
# index     int64
# id        int64
# name     object
# dtype: object

# %%
df["id"].dtype
df["id"] = df["id"].astype("category")

# %%
df["id"]
# Out:
# 0    444
# 1    555
# 2    666
# 3    777
# Name: id, dtype: category
# Categories (4, int64): [444, 555, 666, 777]

# %%
cat_cols = ["index","id"]
num_cols = ["id"]
df[cat_cols] = df[cat_cols].astype("int")

# %%
df.head(2)
# Out:
#   index   id name
# 0     1  444  abc
# 1     2  555  def

# %%
df.describe(include="category")
# Out:
#          id
# count     4
# unique    4
# top     444
# freq      1

# %%
df["id"].nunique()
# Out:
# 4

# %%
df.columns
# Out:
# Index(['index', 'id', 'name'], dtype='object')

# %%
df["id"].max()
# Out:
# np.int64(777)

# %%
df["name"].max()
# Out:
# 'xyz'

# %%
df["id"].idxmax()
# Out:
# 3

# %%
df["id"].min()
# Out:
# np.int64(444)

# %%
df["id"].idxmax()
# Out:
# 3

# %%
def get_feature():
# Out:
#   Cell In[40], line 2
#
#
#
#     ^
#
# SyntaxError: incomplete input

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   4 non-null      int64
#  1   id      4 non-null      int64
#  2   name    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
d = df["id"].value_counts()
d
# Out:
# id
# 444    1
# 555    1
# 666    1
# 777    1
# Name: count, dtype: int64

# %%
df["id"].sum()
# Out:
# np.int64(2442)

# %%
df.max()
# Out:
# index      4
# id       777
# name     xyz
# dtype: object

# %%
df["id"].values
# Out:
# array([444, 555, 666, 777])

# %%
df.values
# Out:
# array([[1, 444, 'abc'],
#        [2, 555, 'def'],
#        [3, 666, 'ghi'],
#        [4, 777, 'xyz']], dtype=object)

# %%
df.replace(666,"Mohamed")
# Out:
#    index       id name
# 0      1      444  abc
# 1      2      555  def
# 2      3  Mohamed  ghi
# 3      4      777  xyz

# %%
df.replace("Mohamed",666)
# Out:
#    index   id name
# 0      1  444  abc
# 1      2  555  def
# 2      3  666  ghi
# 3      4  777  xyz

# %%
df.replace({444:"Ahmed",777:444})
# Out:
#    index     id name
# 0      1  Ahmed  abc
# 1      2    555  def
# 2      3    666  ghi
# 3      4    444  xyz

# %%
def duplicated(x):
    return x * 2

# %%
df["id"].apply(duplicated)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3    1554
# Name: id, dtype: int64

# %%
df["id"].apply(lambda x: x*2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3    1554
# Name: id, dtype: int64

# %%
df.id
# Out:
# 0    444
# 1    555
# 2    666
# 3    777
# Name: id, dtype: int64

# %%
df.id.iloc[2]
# Out:
# np.int64(666)

# %%
df.iloc[2,1]
# Out:
# np.int64(666)

# %%
df.iloc[:, 0:2]
# Out:
#    index   id
# 0      1  444
# 1      2  555
# 2      3  666
# 3      4  777

# %%
data =  [[1,444,"abc",],
         [2,555,"def"],
         [3,666,"ghi"],
         [4,777,"xyz"]]
df  = pd.DataFrame(data, columns=["idx","id","name"])
display(df)
new_column = df.id + df.idx
new_column
# Out:
#    idx   id name
# 0    1  444  abc
# 1    2  555  def
# 2    3  666  ghi
# 3    4  777  xyz
# 0    445
# 1    557
# 2    669
# 3    781
# dtype: int64

# %%
df["new_col"] = df.id + df.idx

# %%
df
# Out:
#    idx   id name  new_col
# 0    1  444  abc      445
# 1    2  555  def      557
# 2    3  666  ghi      669
# 3    4  777  xyz      781

# %%
df.drop("new_col", axis= 1)
# Out:
#    idx   id name
# 0    1  444  abc
# 1    2  555  def
# 2    3  666  ghi
# 3    4  777  xyz

# %%
new_row = {"id": 9,
           "idx": 99,
           "name":"welcome"}
df.append[new_row]
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_4444\2933888865.py in ?()
#
#       1 new_row = {"id": 9,
#
#       2            "idx": 99,
#
#       3            "name":"welcome"}
#
# ----> 4 df.append(new_row)
#
#
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#
#    6317             and name not in self._accessors
#
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#
#    6319         ):
#
#    6320             return self[name]
#
# -> 6321         return object.__getattribute__(self, name)
#
#
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df = pd.concat([df,pd.DataFrame(new_row)],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[87], line 1
#
# ----> 1 df = pd.concat([df,pd.DataFrame(new_row)],ignore_index=True)
#
#
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#
#     776     mgr = self._init_mgr(
#
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#
#     778     )
#
#     780 elif isinstance(data, dict):
#
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
#
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#
#     783 elif isinstance(data, ma.MaskedArray):
#
#     784     from numpy.ma import mrecords
#
#
#
# ...

# %%
null = df.isnull()
pd.DataFrame(null.sum()).T
# Out:
#    idx  id  name  new_col
# 0    0   0     0        0

# %%
def ck_null():
    null = df.isnull()
    pd.DataFrame(null.sum()).T

# %%
df.dropna(subset="id")
# Out:
#    idx   id name  new_col
# 0    1  444  abc      445
# 1    2  555  def      557
# 2    3  666  ghi      669
# 3    4  777  xyz      781

# %%
mean = df.id.mean()
mean
# Out:
# np.float64(610.5)

# %%
df.name = df.name.fillna(value= mean)
df.name
# Out:
# 0    abc
# 1    def
# 2    ghi
# 3    xyz
# Name: name, dtype: object

# %%
df.mode()
# Out:
#    idx   id name  new_col
# 0    1  444  abc      445
# 1    2  555  def      557
# 2    3  666  ghi      669
# 3    4  777  xyz      781
